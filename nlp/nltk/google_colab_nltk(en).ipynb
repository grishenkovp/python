# %%
# Импорт библиотек
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

from nltk import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Токенизация по предложениям

# %%
text = """London is the capital and largest city of England and the United Kingdom. 
The city stands on the River Thames in the south-east of England, at the head of its 50-mile (80 km) estuary leading to the North Sea."""

sentences = sent_tokenize(text)
for sentence in sentences:
    print(sentence)
    print()
# Out:
# London is the capital and largest city of England and the United Kingdom.
#
# The city stands on the River Thames in the south-east of England, at the head of its 50-mile (80 km) estuary leading to the North Sea.

# %% [markdown]
# Токенизация по словам

# %%
for sentence in sentences:
    words = word_tokenize(sentence)
    print(words)
    print()
# Out:
# ['London', 'is', 'the', 'capital', 'and', 'largest', 'city', 'of', 'England', 'and', 'the', 'United', 'Kingdom', '.']
#
# ['The', 'city', 'stands', 'on', 'the', 'River', 'Thames', 'in', 'the', 'south-east', 'of', 'England', ',', 'at', 'the', 'head', 'of', 'its', '50-mile', '(', '80', 'km', ')', 'estuary', 'leading', 'to', 'the', 'North', 'Sea', '.']

# %% [markdown]
# Лемматизация и стемминг текста

# %%
# Стемминг – отрезание от корня слова всего "слишнего"
# Лемматизация – приведение слова к канонической форме (лемме)

# %%
def compare_stemmer_and_lemmatizer(stemmer, lemmatizer, word, pos):
    print("Stemmer:", stemmer.stem(word))
    print("Lemmatizer:", lemmatizer.lemmatize(word, pos))
    print()

lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
compare_stemmer_and_lemmatizer(stemmer, lemmatizer, word = "his", pos = wordnet.VERB)
compare_stemmer_and_lemmatizer(stemmer, lemmatizer, word = "was", pos = wordnet.VERB)
# Out:
# Stemmer: hi
# Lemmatizer: his
#
# Stemmer: wa
# Lemmatizer: be

# %% [markdown]
# Стоп-слова

# %%
stop_words = set(stopwords.words("english"))

words = word_tokenize(text)
without_stop_words = [word for word in words if not word in stop_words]
print(without_stop_words)
# Out:
# ['London', 'capital', 'largest', 'city', 'England', 'United', 'Kingdom', '.', 'The', 'city', 'stands', 'River', 'Thames', 'south-east', 'England', ',', 'head', '50-mile', '(', '80', 'km', ')', 'estuary', 'leading', 'North', 'Sea', '.']

# %% [markdown]
# Мешок слов

# %%
# Определить словарь известных слов (токенов). Выбрать степень присутствия известных слов. Любая информация о порядке или структуре слов игнорируется.

list_text =[]

sentences = sent_tokenize(text)
for sentence in sentences:
    list_text.append(sentence)

count_vectorizer = CountVectorizer()
bag_of_words = count_vectorizer.fit_transform(list_text)

feature_names = count_vectorizer.get_feature_names()
pd.DataFrame(bag_of_words.toarray(), columns = feature_names)
# Out:
#    50  80  and  at  capital  city  ...  south  stands  thames  the  to  united
# 0   0   0    2   0        1     1  ...      0       0       0    2   0       1
# 1   1   1    0   1        0     1  ...      1       1       1    5   1       0
#
# [2 rows x 30 columns]

# %% [markdown]
# TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer()
values = tfidf_vectorizer.fit_transform(list_text)

feature_names = tfidf_vectorizer.get_feature_names()
pd.DataFrame(values.toarray(), columns = feature_names)
# Out:
#          50        80       and  ...       the        to    united
# 0  0.000000  0.000000  0.543452  ...  0.386671  0.000000  0.271726
# 1  0.169776  0.169776  0.000000  ...  0.603984  0.169776  0.000000
#
# [2 rows x 30 columns]
